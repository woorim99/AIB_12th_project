# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !unzip "/content/drive/My Drive/Colab Notebooks/yolo/darknet.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: darknet/build/darknet/x64/data/labels/72_1.png
#   inflating: darknet/build/darknet/x64/data/labels/72_2.png
#   inflating: darknet/build/darknet/x64/data/labels/72_3.png
#   inflating: darknet/build/darknet/x64/data/labels/72_4.png
#   inflating: darknet/build/darknet/x64/data/labels/72_5.png
#   inflating: darknet/build/darknet/x64/data/labels/72_6.png
#   inflating: darknet/build/darknet/x64/data/labels/72_7.png
#   inflating: darknet/build/darknet/x64/data/labels/73_0.png
#   inflating: darknet/build/darknet/x64/data/labels/73_1.png
#   inflating: darknet/build/darknet/x64/data/labels/73_2.png
#   inflating: darknet/build/darknet/x64/data/labels/73_3.png
#   inflating: darknet/build/darknet/x64/data/labels/73_4.png
#   inflating: darknet/build/darknet/x64/data/labels/73_5.png
#   inflating: darknet/build/darknet/x64/data/labels/73_6.png
#   inflating: darknet/build/darknet/x64/data/labels/73_7.png
# ...

# %%
# %cd /content/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# make: Warning: File 'results' has modification time 21661 s in the future
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/YOLOv3_weight/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (235 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/obj.data
# !dos2unix ./data/obj.names
# !dos2unix ./cfg/yolov3.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: ./data/val.txt: No such file or directory
# dos2unix: Skipping ./data/val.txt, not a regular file.
# dos2unix: converting file ./data/obj.data to Unix format...
# dos2unix: converting file ./data/obj.names to Unix format...
# dos2unix: converting file ./cfg/yolov3.cfg to Unix format...

# %%
# %cd /content/darknet
# !./darknet detector train data/obj.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  total_bbox = 1399, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 1402, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# ...

# %%
# !./darknet detector test data/obj.data cfg/yolov3.cfg backup/yolov3_1000.weights data/img/front_accident \(21\).jpg -out out
./darknet detector test data/obj.data cfg/yolov3.cfg backup/yolov3_16800.weights data/img/sample_image.jpg
# Out:
#   File "<ipython-input-1-0862ba26d116>", line 2
#     ./darknet detector test data/obj.data cfg/yolov3.cfg backup/yolov3_16800.weights data/img/sample_image.jpg
#     ^
# SyntaxError: invalid syntax
